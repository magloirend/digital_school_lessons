# %% [markdown]
# # Presentation

# %% [markdown]
# Vous êtes le nouveau Dev OPs d'une startup data 👨‍💻
#
# Vous avez pour objectif de setup l'infrastructure sur GCP qui se composera de différents services :
# **rendez les components dépendants des autres pour les lancer dans le bon ordre**
#
# - Créer une convention de nommage
#
# - Bucket storage
#
# - Cloud functions
#
# - Bigquery table
#
# - Stack driver ( créer un dashboard avec les différents services :cloud  cloud functions, cloud functions, BQ , Stack driver) **( optionnal)**
#
# - rendez le code partageable ( terraform script partageable inside repos GitHub)
#
# **Note : j'utiliserai votre script terraform pour déployer l'infra et vous notez**
#
# *Détail important :
# - commentez votre code, qu'il soit lisible et propre
# - Bien séparer les différents services par modules
# - Créer un read me : détaillant et expliquant votre code

# %% [markdown]
# ## Archi souhaitée :

# %%
from IPython import display
display.Image("/Users/magloirendabagera/Downloads/practice_day_digital_schools.drawio.png")

# %%
#Exemple Readme: 

# terraform-init-gcp

## Description

This action uses `gsutil` to create Cloud Storage Bucket for terraform backend state files. After creating bucket, it runs following terraform commands

- terraform fmt -check
- terraform init
- terraform validate

## Inputs

| parameter | description | required | default |
| - | - | - | - |
| project-id | GCP Project Id | `true` |  |
| tf-backend-bucket-name | Cloud storage bucket name for terraform state file | `true` |  |
| prefix | Prefix for tfstate file in storage bucket for terraform backend | `true` |  |
| terraform-version | Terraform version | `false` | latest |
| working-directory | Location of terraform scripts | `false` | . |

## Runs

This action is a `composite` action.

# %% [markdown]
# **💡Liens utiles💡 :**
#
# - Naming Convention :
#     - https://github.com/MicrosoftDocs/cloud-adoption-framework/blob/main/docs/ready/azure-best-practices/resource-naming.md
#
# - Compte de service :
#     - https://cloud.google.com/iam/docs/service-accounts-create?hl=fr
#
# - Cloud Storage (Bucket):
#     - https://cloud.google.com/storage/docs/creating-buckets?hl=fr#storage-create-bucket-terraform
#
# - Cloud functions :
#      - https://cloud.google.com/functions/docs/create-deploy-gcloud?hl=fr
#
#
# - Terraform :
#     - https://github.com/terraform-google-modules/terraform-docs-samples

# %% [markdown]
# ## Finis ?
#
# Envoyez moi  par mail à magloire.ndabagera@gmail.com un lien vers votre repos pour que je puisse le télécharger et l'essayer en spécifiant comme sujet du mail votre nom + pr2
